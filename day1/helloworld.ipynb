# %% [markdown]
# **快捷键**

# %% [markdown]
# * ctrl + enter 运行当前单元块代码
# * a键 在当前单元块上面加一个单元块
# * b键 在当前单元块下面加一个单元块
# * m或y切换单元块的属性切换（代码/markdown）
# * d+d 删除停留的单元块

# %%
print('hello world!')
# Out:
# hello world!
